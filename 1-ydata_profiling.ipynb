# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Load your dataset
df = pd.read_csv('insurance_claims.csv')

# Create the profile report WITHOUT 'dark_mode'
profile = ProfileReport(
    df,
    title="Insurance Claims EDA Report",
    explorative=True,
    correlations={
        "pearson": {"calculate": True},
        "spearman": {"calculate": True},
        "kendall": {"calculate": False},
        "phi_k": {"calculate": True},
        "cramers": {"calculate": True}
    },
    missing_diagrams={
        "heatmap": True,
        "dendrogram": True
    },
    samples={"head": 5, "tail": 5}
)

# Save the report as an HTML file
profile.to_file("insurance_claims_eda_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/40 [00:00<?, ?it/s]
#  10%|█         | 4/40 [00:00<00:01, 32.40it/s]
#  20%|██        | 8/40 [00:00<00:00, 33.85it/s]
#  32%|███▎      | 13/40 [00:00<00:00, 32.60it/s]
#  45%|████▌     | 18/40 [00:00<00:00, 37.91it/s]
#  55%|█████▌    | 22/40 [00:00<00:00, 33.10it/s]
#  65%|██████▌   | 26/40 [00:00<00:00, 34.32it/s]
#  78%|███████▊  | 31/40 [00:00<00:00, 35.96it/s]
# 100%|██████████| 40/40 [00:01<00:00, 39.48it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
